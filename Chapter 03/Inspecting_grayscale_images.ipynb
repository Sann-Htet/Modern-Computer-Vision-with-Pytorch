# %%
# !wget https://akns-images.eonline.com/eol_images/Entire_Site/2013918/rs_634x951-131018132053-634.cumberbatch-parades-end.jpg

# %%
import cv2
import matplotlib.pyplot as plt

img = cv2.imread('cumberbatch.jpg')

# %%
import numpy as np
np.array(img).shape
# Out:
# (951, 634, 3)

# %%
# crop image
img = img[100:300, 200:400]

# %%
# Convert image to grayscale
img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
# Show image
plt.imshow(img_gray, cmap='gray')

# %%
img_gray_small = cv2.resize(img_gray, (25, 25))
plt.imshow(img_gray_small, cmap="gray")

# %%
print(img_gray_small)
# Out:
# [[229 202 197 188 135  76  59  84 101  80 101  61  61 107 102  56  53  59
#    68  68  61 111 115 212 245]
#  [233 208 203 177  93  87  80  82  78 105 124 116 135 160 181  96  75  91
#   132 142 124 105 118  85 224]
#  [236 213 208 187  67  70  58 115 134 115 108 130 120 118 141 124 159 161
#   153 137 127 113 110  76 168]
#  [239 216 207  40  70  94  95 111 104 107 148 128 132 117  98 113 176 177
#   162 149 133 105 134  99  62]
#  [240 219 205  36  67 124 141 120 130 126 108 133 143 106  87 171 193 181
#   169 154 144 106  47  71  36]
#  [241 221 163  38 107  56 110 143 132  96 118 132 137 146 159 200 198 186
#   175 165 149 107  38  54  50]
#  [242 220 183  46  62 108  83 119 127 115 112 137 203 211 212 201 187 167
#   172 164 152  96  30  55  18]
#  [243 221 194  52  54  21  79 146 180 171 168 196 200 209 205 201 194 180
#   162 165 151  99  56  14  19]
#  [243 217 194  37  69  23 110 152 175 178 191 202 205 202 201 205 200 189
#   179 176 159 123  86  16  19]
# ...

# %%
img = cv2.imread('cumberbatch.jpg')
img = img[100:300, 200:400, :]
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(img)
print(img.shape)
# Out:
# (200, 200, 3)

# %%
crop = img[-3:, -3:]
print(crop)
plt.imshow(crop)
# Out:
# [[[179 182 173]
#   [186 191 184]
#   [190 195 188]]
#
#  [[175 178 169]
#   [182 187 180]
#   [187 192 186]]
#
#  [[173 174 168]
#   [180 182 177]
#   [186 188 183]]]

# %% [markdown]
# ---
