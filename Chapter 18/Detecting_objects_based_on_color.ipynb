# %%
# !wget https://www.dropbox.com/s/utrkdooh08y9mvm/uno_card.png
# !pip install -q torch_snippets
from torch_snippets import *
import cv2, numpy as np
# Out:
# --2023-10-23 12:04:40--  https://www.dropbox.com/s/utrkdooh08y9mvm/uno_card.png
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.3.18, 2620:100:6018:18::a27d:312
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.3.18|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: /s/raw/utrkdooh08y9mvm/uno_card.png [following]
# --2023-10-23 12:04:40--  https://www.dropbox.com/s/raw/utrkdooh08y9mvm/uno_card.png
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uc7cb29ab1488f08f43b310e1dde.dl.dropboxusercontent.com/cd/0/inline/CGLCX_HxQ2JffLwxKLJ4CghyeepWMZFRdxImQxcq1cauqx0zNXHOgM1gLnCGvsUNUrfLne1L3EK4sfX_jxFOnrPqbWR3-3ipZ2Jc55XD1JYM2-HzWWewM3Ds5cTgvXCqEtfuwCNtBQHXANNuQAOzBdUc/file# [following]
# --2023-10-23 12:04:40--  https://uc7cb29ab1488f08f43b310e1dde.dl.dropboxusercontent.com/cd/0/inline/CGLCX_HxQ2JffLwxKLJ4CghyeepWMZFRdxImQxcq1cauqx0zNXHOgM1gLnCGvsUNUrfLne1L3EK4sfX_jxFOnrPqbWR3-3ipZ2Jc55XD1JYM2-HzWWewM3Ds5cTgvXCqEtfuwCNtBQHXANNuQAOzBdUc/file
# Resolving uc7cb29ab1488f08f43b310e1dde.dl.dropboxusercontent.com (uc7cb29ab1488f08f43b310e1dde.dl.dropboxusercontent.com)... 162.125.80.15, 2620:100:6018:15::a27d:30f
# Connecting to uc7cb29ab1488f08f43b310e1dde.dl.dropboxusercontent.com (uc7cb29ab1488f08f43b310e1dde.dl.dropboxusercontent.com)|162.125.80.15|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 90167 (88K) [image/png]
# Saving to: ‘uno_card.png’
#
# uno_card.png        100%[===================>]  88.05K   154KB/s    in 0.6s
#
# 2023-10-23 12:04:43 (154 KB/s) - ‘uno_card.png’ saved [90167/90167]
#
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.4/65.4 kB 2.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.3/115.3 kB 5.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.5/62.5 kB 7.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.6/78.6 kB 10.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 203.7/203.7 kB 12.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 52.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 33.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.9/98.9 kB 12.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.7/3.7 MB 63.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 30.6/30.6 MB 44.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 169.4/169.4 kB 22.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 95.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 468.9/468.9 kB 52.5 MB/s eta 0:00:00
#   Building wheel for typing (setup.py) ... done

# %%
img = read('uno_card.png', 1)
show(img)
hsv = cv2.cvtColor(img, cv2.COLOR_RGB2HSV)

# %%
lower_green = np.array([45,100,100])
upper_green = np.array([80,255,255])

# %%
mask = cv2.inRange(hsv, lower_green, upper_green)

# %%
res = cv2.bitwise_and(img, img, mask=mask)
subplots([img, mask, res], nc=3, figsize=(10, 5),
         titles=['Original image', 'Mask on image', 'Resulting image'])

# %% [markdown]
# ---
